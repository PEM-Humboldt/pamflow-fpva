# %%
# %reload_kedro
# Out:
# [04/24/26 11:51:05] INFO     Resolved project path as:                                              ]8;id=443276;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\pamflow_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=835403;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\pamflow_env\lib\site-packages\kedro\ipython\__init__.py#175\175]8;;\
#                              C:\Users\nicolas.betancourt\Documents\GitHub\pamflow-fpva.
#                              To set a different path, run '%reload_kedro <project_root>'
# [04/24/26 11:51:06] INFO     Kedro project pamFlow                                                  ]8;id=411405;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\pamflow_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=68694;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\pamflow_env\lib\site-packages\kedro\ipython\__init__.py#141\141]8;;\
# ...

# %%
import pandas as pd
import numpy as np

# %%
#thresholds=catalog.load("unfiltered_observations@pamDP")
observations=catalog.load("observations@pamDP")
# Out:
# [04/24/26 11:51:53] INFO     Loading data from observations@pamDP (Observations)...             ]8;id=814099;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\pamflow_env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=66526;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\pamflow_env\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\

# %%
observations
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       observationID deploymentID                  mediaID  eventID  \
# 0             20584          G01  G01_20250908_080000.WAV      NaN
# 1             20585          G01  G01_20250908_080000.WAV      NaN
# 2             20588          G01  G01_20250908_080000.WAV      NaN
# 3             20589          G01  G01_20250908_080000.WAV      NaN
# 4             20592          G01  G01_20250908_080000.WAV      NaN
# ...             ...          ...                      ...      ...
# 3273         104986          G23  G23_20250910_100000.WAV      NaN
# 3274         104988          G23  G23_20250910_100000.WAV      NaN
# 3275         104989          G23  G23_20250910_100000.WAV      NaN
# 3276         104990          G23  G23_20250910_100000.WAV      NaN
# 3277         108094          G14  G14_20250912_110000.WAV      NaN
#
# ...
